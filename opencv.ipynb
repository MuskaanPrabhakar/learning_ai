# %% [markdown]
# <a href="https://colab.research.google.com/github/MuskaanPrabhakar/learning_ai/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python

# %%
import cv2
cv2.__version__

# %%
image =cv2.imread("Screenshot 2026-07-16 152933.png")

# %%
image

# %%
image.size

# %%
new = cv2.resize(image,(300,300))

# %%
cv2.imwrite("new.jpg", image)

# %%
image

# %%
cv2.circle(
    image,
    (100,100),#center
    50,
    (0,0,225),
    2
)

# %%
from google.colab.patches import cv2_imshow
import cv2
image= cv2.imread("Screenshot 2026-07-16 152933.png")
if image is None:
  print("image not found")
else:
  cv2_imshow(image)

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

uploaded = files.upload()
filename = list(uploaded.keys())[0]

image = cv2.imread(filename)

if image is None:
    raise ValueError("Could not read the image.")

print("Original Image")
cv2_imshow(image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

print(f"\nTotal Faces Detected: {len(faces)}")

for i, (x, y, w, h) in enumerate(faces, start=1):

    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 3)

    cv2.putText(
        image,
        f"Face {i}",
        (x, y - 10),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 0, 0),
        2
    )

    print(f"Face {i}")
    print(f"Location: x={x}, y={y}, width={w}, height={h}")

    face = image[y:y+h, x:x+w]

    print(f"Cropped Face {i}")
    cv2_imshow(face)

print("\nFinal Detection Result")
cv2_imshow(image)

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files

uploaded = files.upload()
filename = list(uploaded.keys())[0]

image = cv2.imread(filename)

if image is None:
    raise ValueError("Could not read the image.")

new_width = 800

height, width = image.shape[:2]
aspect_ratio = height / width
new_height = int(new_width * aspect_ratio)

image = cv2.resize(image, (new_width, new_height))

print(f"Resized Image: {new_width} x {new_height}")

print("Resized Image")
cv2_imshow(image)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# Detect faces
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

print(f"\nTotal Faces Detected: {len(faces)}")

for i, (x, y, w, h) in enumerate(faces, start=1):

    cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 3)

    cv2.putText(
        image,
        f"Face {i}",
        (x, y - 10),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 0, 0),
        2
    )

    print(f"\nFace {i}")
    print(f"Location: x={x}, y={y}, width={w}, height={h}")

    # Crop face
    face = image[y:y+h, x:x+w]

    print(f"Cropped Face {i}")
    cv2_imshow(face)

print("\nFinal Detection Result")
cv2_imshow(image)
